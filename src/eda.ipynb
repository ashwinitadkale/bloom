# %%
import sys
print(sys.executable)
# Out:
# c:\Users\ashwi\Desktop\bloom\venv\Scripts\python.exe

# %%
#!{sys.executable} -m pip install pandas
#!{sys.executable} -m pip install matplotlib
#!{sys.executable} -m pip install seaborn
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: matplotlib in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from matplotlib) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# WARNING: There was an error checking the latest version of pip.
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: seaborn in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\ashwi\desktop\bloom\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# WARNING: There was an error checking the latest version of pip.

# %%
import pandas as pd
import matplotlib as mb
import seaborn as sb

# %%
df=pd.read_csv(r"C:\Users\ashwi\Desktop\bloom\app_py\my_data.csv")

# %%
df.head()
# Out:
#   last_period_start  cycle_length  period_length next_period_start  \
# 0        2020-01-13            31              3        2020-02-13
# 1        2020-12-12            32              3        2021-01-13
# 2        2020-02-17            21              3        2020-03-09
# 3        2020-04-11            21              7        2020-05-02
# 4        2020-01-04            30              5        2020-02-03
#
#   ovulation_day  stress_level  exercise_frequency  diet_quality  \
# 0    2020-01-28             5                   3             4
# 1    2020-12-28             9                   1            10
# 2    2020-02-27             4                   3             9
# 3    2020-04-21             9                   6             4
# 4    2020-01-19             3                   6             6
#
#    sleep_quality  body_temperature
# 0              3              36.8
# 1              7              36.8
# 2             10              36.8
# 3              8              36.8
# 4              5              36.8

# %%
print(df.shape)
print(df.info)
# Out:
# (1000, 10)
# <bound method DataFrame.info of     last_period_start  cycle_length  period_length next_period_start  \
# 0          2020-01-13            31              3        2020-02-13
# 1          2020-12-12            32              3        2021-01-13
# 2          2020-02-17            21              3        2020-03-09
# 3          2020-04-11            21              7        2020-05-02
# 4          2020-01-04            30              5        2020-02-03
# ..                ...           ...            ...               ...
# 995        2020-02-07            25              4        2020-03-03
# 996        2020-05-12            26              3        2020-06-07
# 997        2020-11-08            28              4        2020-12-06
# 998        2020-08-08            23              7        2020-08-31
# 999        2020-02-07            22              3        2020-02-29
#
#     ovulation_day  stress_level  exercise_frequency  diet_quality  \
# 0      2020-01-28             5                   3             4
# 1      2020-12-28             9                   1            10
# 2      2020-02-27             4                   3             9
# 3      2020-04-21             9                   6             4
# 4      2020-01-19             3                   6             6
# ..            ...           ...                 ...           ...
# 995    2020-02-19             5                   0             7
# 996    2020-05-25             5                   2             8
# 997    2020-11-22             7                   2             8
# 998    2020-08-19             4                   1             8
# 999    2020-02-18             2                   4             8
#
#      sleep_quality  body_temperature
# 0                3              36.8
# 1                7              36.8
# 2               10              36.8
# 3                8              36.8
# 4                5              36.8
# ..             ...               ...
# 995              7              36.8
# 996              2              36.8
# 997              2              36.8
# 998              5              36.8
# 999              1              36.8
#
# [1000 rows x 10 columns]>

# %%
print(df.isnull().sum())
# Out:
# last_period_start     0
# cycle_length          0
# period_length         0
# next_period_start     0
# ovulation_day         0
# stress_level          0
# exercise_frequency    0
# diet_quality          0
# sleep_quality         0
# body_temperature      0
# dtype: int64

# %%
import matplotlib.pyplot as plt
sb.countplot(data=df,x='exercise_frequency')
sb.countplot(data=df,x='period_length')
# Out:
# <Axes: xlabel='exercise_frequency', ylabel='count'>
